# %%
import pandas as pd
import json

# %%
with open('k_dict_total_edit.json') as json_data:
    d = json.load(json_data)

# %%
d
# Out:
# {u'57989552,82194466': 1,
#  u'126253589,138032125': 2,
#  u'139058488,961763': 4,
#  u'101511783,150709997': 2,
#  u'46615975,63038823': 4,
#  u'123404744,206309572': 5,
#  u'27626800,160533590': 1,
#  u'338067643994,41864723': 1,
#  u'127685288,210484903': 7,
#  u'67577783,55304218': 1,
#  u'338067138531,204619848': 7,
#  u'6249980,1560909': 1,
#  u'107067109,178265564': 7,
#  u'338066922357,18048949': 1,
#  u'138156928,169259237': 2,
#  u'98493578,198629797': 1,
#  u'81617777,2322159': 3,
#  u'52059797,24258742': 1,
#  u'71882778,45884516': 1,
#  u'110458579,2251372': 1,
#  u'26647987,210065009': 2,
#  u'4743501,2878885': 2,
#  u'22941611,3681549': 1,
#  u'22941611,3681548': 1,
#  u'3544076,45308427': 1,
#  u'22941611,3681545': 2,
#  u'71379081,43508091': 2,
#  u'14163683,136090300': 1,
#  u'22941611,3681542': 1,
#  u'156407144,173777092': 1,
#  u'8696320,2147239': 1,
#  u'126970772,57744412': 4,
#  u'29548823,27473304': 2,
#  u'36591882,139138807': 8,
#  u'6458510,837272': 1,
# ...

# %%
da=pd.DataFrame(d.items())
da
# Out:
#                                0   1
# 0              57989552,82194466   1
# 1            126253589,138032125   2
# 2               139058488,961763   4
# 3            101511783,150709997   2
# 4              46615975,63038823   4
# 5            123404744,206309572   5
# 6             27626800,160533590   1
# 7          338067643994,41864723   1
# 8            127685288,210484903   7
# 9              67577783,55304218   1
# 10        338067138531,204619848   7
# 11               6249980,1560909   1
# 12           107067109,178265564   7
# 13         338066922357,18048949   1
# 14           138156928,169259237   2
# 15            98493578,198629797   1
# 16              81617777,2322159   3
# 17             52059797,24258742   1
# 18             71882778,45884516   1
# 19             110458579,2251372   1
# 20            26647987,210065009   2
# 21               4743501,2878885   2
# 22              22941611,3681549   1
# 23              22941611,3681548   1
# ...

# %%
da.to_csv('finish2',sep='\t',encoding='utf-8',index=False)

# %%
print 'Ok'
# Out:
# Ok
