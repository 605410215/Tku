# %%
import pandas as pd
import json as js

# %%
d=pd.read_csv('abi',sep='\t')
d
# Out:
#                  msno x_login_type    song_id                played_at  \
# 0            93996035      android  121232463  2016-12-15 10:31:59.542
# 1             5814876      android   67288492  2016-12-15 10:19:21.117
# 2        338066753834       iphone    1548161  2016-12-15 10:30:45.840
# 3           110228126       iphone  158987025  2016-12-15 10:29:01.786
# 4            27693001      android  198678060  2016-12-15 10:11:21.895
# 5           128986117        win32    4019985  2016-12-15 10:27:04.000
# 6            68489561      android  196817428  2016-12-15 10:29:04.894
# 7           132044143       iphone   21751523  2016-12-15 10:27:27.370
# 8            48531452       iphone     865599  2016-12-15 10:21:36.425
# 9        338065758156      android  156135706  2016-12-15 10:28:15.358
# 10          135847171      android   88485433  2016-12-15 10:27:23.730
# 11           20779175       iphone  200117561  2016-12-15 10:19:13.328
# ...

# %%
#le=0
#columns=['msno','x_login_type','song_id','played_at','song_length','played_length']
for x in range(98,99,1):
    for y in range(105,123,1):
        m='a'+chr(x) + chr(y)
        #dataset=pd.read_csv(m,sep='\t',names=columns)
        dataset=pd.read_csv(m,sep='\t')
        
        dataset['listen_at']=pd.to_datetime(dataset['played_at'])
        dataset['year'] = dataset['listen_at'].dt.year
        dataset['month'] = dataset['listen_at'].dt.month
        dataset['day'] = dataset['listen_at'].dt.day
        
#        le=le+len(dataset)
        dataset.to_csv(m,sep='\t',encoding='utf-8',index=False)
        print m,
#        print le,
#        if (x==100 and y==108):
#            break
# Out:
# abi abj abk abl abm abn abo abp abq abr abs abt abu abv abw abx aby abz

# %%
#le=0
#columns=['msno','x_login_type','song_id','played_at','song_length','played_length']
for x in range(99,101,1):
    for y in range(97,123,1):
        m='a'+chr(x) + chr(y)
        #dataset=pd.read_csv(m,sep='\t',names=columns)
        dataset=pd.read_csv(m,sep='\t')
        
        dataset['listen_at']=pd.to_datetime(dataset['played_at'])
        dataset['year'] = dataset['listen_at'].dt.year
        dataset['month'] = dataset['listen_at'].dt.month
        dataset['day'] = dataset['listen_at'].dt.day
        
#        le=le+len(dataset)
        dataset.to_csv(m,sep='\t',encoding='utf-8',index=False)
        print m,
#        print le,
        if (x==100 and y==108):
            break
# Out:
# aca acb acc acd ace acf acg ach aci acj ack acl acm acn aco acp acq acr acs act acu acv acw acx acy acz ada adb adc add ade adf adg adh adi adj adk adl

# %%
'''
a=pd.read_csv('abh',sep='\t')
a['listen_at']=pd.to_datetime(a['played_at'])
a['year'] = a['listen_at'].dt.year
a['month'] = a['listen_at'].dt.month
a['day'] = a['listen_at'].dt.day
a
'''
# Out:
# "\na=pd.read_csv('abh',sep='\t')\na['listen_at']=pd.to_datetime(a['played_at'])\na['year'] = a['listen_at'].dt.year\na['month'] = a['listen_at'].dt.month\na['day'] = a['listen_at'].dt.day\na\n"

# %%
#abh
